# %% [markdown]
# # Smoker Prediction

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
train_df = pd.read_csv('../data/train/train.csv', index_col='id')
test_df = pd.read_csv('../data/test/test.csv', index_col='id')

# %%
train_df.head()
# Out:
#     age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# id
# 0    55         165          60       81.0             0.5              0.6
# 1    70         165          65       89.0             0.6              0.7
# 2    20         170          75       81.0             0.4              0.5
# 3    35         180          95      105.0             1.5              1.2
# 4    30         165          60       80.5             1.5              1.0
#
#     hearing(left)  hearing(right)  systolic  relaxation  ...  HDL  LDL  \
# id                                                       ...
# 0               1               1       135          87  ...   40   75
# 1               2               2       146          83  ...   57  126
# 2               1               1       118          75  ...   45   93
# 3               1               1       131          88  ...   38  102
# 4               1               1       121          76  ...   44   93
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159256 entries, 0 to 159255
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   age                  159256 non-null  int64
#  1   height(cm)           159256 non-null  int64
#  2   weight(kg)           159256 non-null  int64
#  3   waist(cm)            159256 non-null  float64
#  4   eyesight(left)       159256 non-null  float64
#  5   eyesight(right)      159256 non-null  float64
#  6   hearing(left)        159256 non-null  int64
#  7   hearing(right)       159256 non-null  int64
#  8   systolic             159256 non-null  int64
#  9   relaxation           159256 non-null  int64
#  10  fasting blood sugar  159256 non-null  int64
#  11  Cholesterol          159256 non-null  int64
#  12  triglyceride         159256 non-null  int64
#  13  HDL                  159256 non-null  int64
#  14  LDL                  159256 non-null  int64
# ...

# %%
train_df.describe()
# Out:
#                  age     height(cm)     weight(kg)      waist(cm)  \
# count  159256.000000  159256.000000  159256.000000  159256.000000
# mean       44.306626     165.266929      67.143662      83.001990
# std        11.842286       8.818970      12.586198       8.957937
# min        20.000000     135.000000      30.000000      51.000000
# 25%        40.000000     160.000000      60.000000      77.000000
# 50%        40.000000     165.000000      65.000000      83.000000
# 75%        55.000000     170.000000      75.000000      89.000000
# max        85.000000     190.000000     130.000000     127.000000
#
#        eyesight(left)  eyesight(right)  hearing(left)  hearing(right)  \
# count   159256.000000    159256.000000  159256.000000   159256.000000
# mean         1.005798         1.000989       1.023974        1.023421
# std          0.402113         0.392299       0.152969        0.151238
# min          0.100000         0.100000       1.000000        1.000000
# ...

# %% [markdown]
# ## Feature Selection and Engineering

# %%
from sklearn.feature_selection import mutual_info_classif
X, Y = train_df.drop(['smoking'], axis=1), train_df['smoking']

# %%
mi_scores = mutual_info_classif(X, Y, discrete_features='auto')
mi_df = pd.DataFrame({'Feature': X.columns, 'Score': mi_scores})
mi_df = mi_df.sort_values(by='Score', ascending=False)

# %%
mi_df
# Out:
#                 Feature     Score
# 1            height(cm)  0.138278
# 15           hemoglobin  0.133632
# 20                  Gtp  0.101342
# 2            weight(kg)  0.081787
# 12         triglyceride  0.076515
# 17     serum creatinine  0.061954
# 3             waist(cm)  0.044223
# 13                  HDL  0.041652
# 19                  ALT  0.028676
# 0                   age  0.026267
# 16        Urine protein  0.018338
# 9            relaxation  0.016580
# 6         hearing(left)  0.015804
# 7        hearing(right)  0.015721
# 4        eyesight(left)  0.014761
# 5       eyesight(right)  0.014036
# 8              systolic  0.011216
# 14                  LDL  0.010080
# 10  fasting blood sugar  0.008962
# 21        dental caries  0.008646
# 11          Cholesterol  0.006533
# 18                  AST  0.004825

# %%
train_df['BMI'] =  train_df['weight(kg)'] / train_df['height(cm)']**2
train_df['WHtR'] = train_df['waist(cm)'] / train_df['height(cm)']

train_df['scaled_BMI'] = train_df['BMI'] * train_df['WHtR']

train_df['pulse_pressure'] = train_df['systolic'] - train_df['relaxation']

train_df.drop(['weight(kg)', 'height(cm)', 'waist(cm)', 'eyesight(left)', 'eyesight(right)', 'hearing(left)', 
               'hearing(right)', 'BMI', 'WHtR', 'Cholesterol', 'Urine protein', 'systolic', 'relaxation'],
              axis=1, inplace=True)

# %%
corr_matrix = train_df.corr()

# %%
plt.figure(figsize=(16, 16))
sns.heatmap(corr_matrix, annot=True, fmt='.2f')
plt.show()

# %%
def get_in_features(df):
    input_features = {}

    for col in train_df.columns:
        input_features[col] = (min(df[col]), max(df[col]))

    return input_features

# %%
in_features = get_in_features(train_df)

# %%
drop_features = ['weight(kg)', 'height(cm)', 'waist(cm)', 'eyesight(left)', 'eyesight(right)', 'hearing(left)', 
               'hearing(right)', 'BMI', 'WHtR', 'Cholesterol', 'Urine protein', 'systolic', 'relaxation']

# %%
len(train_df.columns)
# Out:
# 14

# %%
plt.figure(figsize=(15, 20))

for i, col in enumerate(train_df.columns):
    if i==11:
        continue
    else:
        plt.subplot(7, 2, i+1)
        sns.boxplot(train_df[col])
        plt.title(col)
        
plt.show()

# %%
plt.figure(figsize=(15, 25))

for i, col in enumerate(train_df.columns):
    if i==11:
        continue
    else:
        plt.subplot(7, 2, i+1)
        sns.histplot(train_df[col], kde=True)
        # plt.title(col)
        
plt.show()

# %% [markdown]
# ## Model Training

# %%
from sklearn.model_selection import train_test_split
X = train_df.drop(['smoking'], axis=1)
Y = train_df['smoking']
x_train, x_val, y_train, y_val = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import QuantileTransformer
scaler = QuantileTransformer()
x_train_scaled = scaler.fit_transform(x_train)
x_val_scaled = scaler.transform(x_val)

# %%
x_train.shape
# Out:
# (111479, 13)

# %%
plt.figure(figsize=(15, 20))

for i in range(x_train_scaled.shape[1]):
    if i==11:
        continue
    else:
        plt.subplot(7, 2, i+1)
        sns.boxplot(x_train_scaled[:,i])
        plt.title(f'Column {i}')
        
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

# %%
lr = LogisticRegression()
dtc = DecisionTreeClassifier()
rfc = RandomForestClassifier()
svc = LinearSVC()

# %%
lr.fit(x_train_scaled, y_train)
dtc.fit(x_train_scaled, y_train)
rfc.fit(x_train_scaled, y_train)
svc.fit(x_train_scaled, y_train)
# Out:
# LinearSVC()

# %%
# validating models
lr_preds = lr.predict(x_val_scaled)
dtc_preds = dtr.predict(x_val_scaled)
rfc_preds = rfr.predict(x_val_scaled)
svc_preds = svc.predict(x_val_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
print(f'Accuracy: {round(accuracy_score(y_val, lr_preds), 4) * 100} %')
print(f'Accuracy: {round(accuracy_score(y_val, dtc_preds), 4) * 100} %')
print(f'Accuracy: {round(accuracy_score(y_val, rfc_preds), 4) * 100} %')
print(f'Accuracy: {round(accuracy_score(y_val, svc_preds), 4) * 100} %')
# Out:
# Accuracy: 74.76 %
# Accuracy: 68.02 %
# Accuracy: 76.58 %
# Accuracy: 74.91 %

# %% [markdown]
# ## Model Testing

# %%
test_df['BMI'] =  test_df['weight(kg)'] / test_df['height(cm)']**2
test_df['WHtR'] = test_df['waist(cm)'] / test_df['height(cm)']

test_df['scaled_BMI'] = test_df['BMI'] * test_df['WHtR']

test_df['pulse_pressure'] = test_df['systolic'] - test_df['relaxation']

test_df.drop(['weight(kg)', 'height(cm)', 'waist(cm)', 'eyesight(left)', 'eyesight(right)', 'hearing(left)', 
               'hearing(right)', 'BMI', 'WHtR', 'Cholesterol', 'Urine protein', 'systolic', 'relaxation'],
              axis=1, inplace=True)

# %%
test_df.columns
# Out:
# Index(['age', 'fasting blood sugar', 'triglyceride', 'HDL', 'LDL',
#        'hemoglobin', 'serum creatinine', 'AST', 'ALT', 'Gtp', 'dental caries',
#        'scaled_BMI', 'pulse_pressure'],
#       dtype='object')

# %%
test_df = scaler.transform(test_df)

# %%
lr_test_preds = lr.predict(test_df)
dtc_test_preds = dtr.predict(test_df)
rfc_test_preds = rfr.predict(test_df)
svc_test_preds = svc.predict(test_df)

# %%
# from pickle import dump
# with open('../models/quartile_transformer.pkl', 'wb') as f:
#     dump(scaler, f)

# %%
# from pickle import dump

# with open('../models/logistic_regression.pkl', 'wb') as f:
#     dump(lr, f)

# with open('../models/decision_tree_regressor.pkl', 'wb') as f:
#     dump(dtc, f)

# with open('../models/random_forest_regressor.pkl', 'wb') as f:
#     dump(rfc, f)

# with open('../models/support_vector_machines.pkl', 'wb') as f:
#     dump(svc, f)

# %%
from sklearn.metrics import confusion_matrix

# %%
lr_cm = confusion_matrix(y_val, lr_preds)
dtc_cm = confusion_matrix(y_val, dtc_preds)
rfc_cm = confusion_matrix(y_val, rfc_preds)
svc_cm = confusion_matrix(y_val, svc_preds)

# %%
fig, ax = plt.subplots(2,2, figsize=(15, 15))
fig.suptitle('Confusion Matrices')

plt.subplot(2,2, 1)
sns.heatmap(lr_cm, annot=True, cbar=False, fmt='.2g')
plt.title('Logistic Regression')

plt.subplot(2,2, 2)
sns.heatmap(dtc_cm, annot=True, cbar=False, fmt='.2g')
plt.title('Decision Tree Classifier')

plt.subplot(2,2, 3)
sns.heatmap(rfc_cm, annot=True, cbar=False, fmt='.2g')
plt.title('Random Forest Classifier')

plt.subplot(2,2, 4)
sns.heatmap(svc_cm, annot=True, cbar=False, fmt='.2g')
plt.title('Support Vector Machines')

plt.savefig('../reports/Confusion_Matrices.png')
